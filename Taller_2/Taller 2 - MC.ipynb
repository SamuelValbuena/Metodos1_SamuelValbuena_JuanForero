# %% [markdown]
# # Punto 7

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import sympy as sym
from scipy.integrate import quad
from scipy.integrate import dblquad

# %%
n = 200
x = np.linspace(-1,1,n+1)
y = np.linspace(-1,1,n+1)

a = 0.
b = x[-1]

R = 1

# %%
def f(x,y,R=1.):
    
    z = R**2 - x**2 - y**2
    
    if z <= 0.:
        return 0.
    else:
        return np.sqrt(z)

# %%
f = np.vectorize(f)

# %%
X,Y = np.meshgrid(x,y)
Z = f(X,Y)

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z,cmap='coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def integral():
    integ = 0
    for i in range(n):
        for j in range(n):
            promedio = (f(x[j],y[i])+f(x[j+1],y[i])+f(x[j],y[i+1])+f(x[j+1],y[i+1]))/4
            prom_area = (4/40000)*promedio
            integ += prom_area

    return integ

# %%
integral()
# Out:
# 2.094319584107527

# %% [markdown]
# # Punto 14

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from scipy import integrate
from numpy.polynomial.polynomial import Polynomial
# Out:
# <style>.container { width:100% !important; }</style>

# %%
sym.init_printing()

# %%
x = sym.Symbol('x',real=True)
y = sym.Symbol('y',real=True)

# %%
n=2

# %%
def GetLegendre(n,x,y):
    
    y = (x**2 - 1)**n
    
    poly = sym.diff( y,x,n )/(2**n * np.math.factorial(n))
    
    return poly

# %%
Legendre = []
DLegendre = []

for i in range(n+1):
    
    Pol = GetLegendre(i,x,y)
    Legendre.append(Pol)
    DLegendre.append( sym.diff(Poly,x,1) )

# %%
Leg0=Legendre[0]*x
Leg0
# Out:
# x

# %%
Poly0 = sym.Poly(Leg0)/x
Poly1 = sym.Poly(Legendre[1])
Poly2 = sym.Poly(Legendre[2])

# %%
Poly_ = sym.Poly(3+5*x+x**2)

# %% [markdown]
# Iniciamos buscando el coeficiente que acompaña al cuadrado, que será el mismo que acompaña a p2

# %%
equiscuadrado_ = Poly_ - 3 - 5*x

# %%
equiscuadradop2 = Poly2 + 0.5

# %%
coef_p2 = cuadrado_/cuadrado2

# %%
coef_p2
# Out:
# 0.666666666666667

# %% [markdown]
# Ahora buscamos el coeficiente que acompaña a p1

# %%
equis_ = Poly_ - 3 - x**2

# %%
coef_p1 = equis_ / Poly1

# %%
coef_p1
# Out:
# 5

# %% [markdown]
# Finalmente, buscamos el coeficiente que acompaña a p0, considerando que ya tenemos 0.5 unidades que hacen parte de p2

# %%
numero_ = Poly_ - 5*x - x**2 + 1/3

# %%
numerop0 = Poly0

# %%
coef_p0 = numero_/numerop0

# %%
coef_p0
# Out:
# 3.33333333333333

# %% [markdown]
# Entonces, la expresión final será:

# %%
polinomio_ = coef_p0*(Poly0)+coef_p1*(Poly1)+coef_p2*(Poly2)

# %%
polinomio_
# Out:
# Poly(1.0*x**2 + 5.0*x + 3.0, x, domain='RR')
