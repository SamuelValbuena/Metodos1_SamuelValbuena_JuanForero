# %% [markdown]
# # Estimacion de la velocidad de rotacion terrestre

# %% [markdown]
# ## A) Descarguen los datos experimentales de cada canal de observacion.

# %%
import os
import wget
import pandas as pd
import numpy as np
import scipy.optimize as spo
import matplotlib.pyplot as plt

data_folder = 'Data'
if not os.path.exists(data_folder):
    os.mkdir(data_folder)

data_file = os.path.join(data_folder, 'DataRotacion.csv')
data_url = 'https://raw.githubusercontent.com/asegura4488/Database/main/MetodosComputacionalesReforma/DataRotacion.csv'

if not os.path.exists(data_file):
    wget.download(data_url, data_file)
    print('File loaded')

# %% [markdown]
# ## B) Cargue los datos usando Pandas y haga un filtrado para obtener los datos correspondientes a λ = 30.

# %%
data = pd.read_csv(data_file)
angle_filter = data['angle'] == 30
filtered_data = data[angle_filter].copy()
h_values = np.array(filtered_data['h'])
y_values = np.array(filtered_data['y'])
sigmay_values = np.array(filtered_data['sigmay'])

# %% [markdown]
# ## C) Defina el modelo fisico presentado para la desviacion por efecto coriolis. El modelo debe tener como entrada la altura inicial de caida h, el parametro de ajuste p = ω, la latitud λ y la aceleracion de la gravedad g.

# %%
def coriolis_model(h, lamb, p, g=9.81):
    y = 2 * np.sqrt(2) * (1 / 3) * p * np.cos(np.deg2rad(lamb)) * np.sqrt(h**3 / g)
    return y

# %% [markdown]
# ## D) Defina la funcion χ^2, donde los argumentos son (h, y, sigmay, angle, g)

# %%
def funcion(p, h, y, sigmay, g=9.81, angle=30):
    model = coriolis_model(h, angle, p, g)
    residuals = y - model
    chi2 = np.sum(residuals**2 / (2 * sigmay**2))
    return chi2

# %% [markdown]
# ## E) Minimice usando optimize. Para λ = 30, deberia obtener ω = 7.24 × 10^−5

# %%
p0 = np.ones(1)
minimize_options = {'disp': True}
result = spo.minimize(funcion, p0, args=(h_values, y_values, sigmay_values), options=minimize_options)
omega = result.x[0]
print("ω es:", omega)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.145718
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# ω es: 7.243998042010375e-05

# %% [markdown]
# ## F) Dibuje los datos y el modelo para esa latitud.

# %%
h_model = np.linspace(np.min(h_values), np.max(h_values), 100)
y_model = coriolis_model(h_model, 30, omega)
plt.errorbar(h_values, y_values, yerr=sigmay_values, fmt='o', color='blue', label="Datos")
plt.plot(h_model, y_model, 'r', label="Modelo")
plt.xlabel("h(m)")
plt.ylabel("y(m)")
plt.title("Desviación de Coriolis como función de la altura para la latitud λ = 30")
plt.legend()
plt.show()

# %%
N = 300
Gravedad = np.zeros(N)
Omega = np.zeros(N)
for i in range(N):
    g = 9.81 + np.random.normal(loc=0, scale=1)
    Gravedad[i] = g
    y_modificado = y_values + np.random.normal(loc=0, scale=sigmay_values[0], size=len(y_values))
    result = spo.minimize(funcion, p0, args=(h_values, y_modificado, sigmay_values, g, 30), options=minimize_options)
    omega = result.x[0]
    Omega[i] = omega

num_bins = 10
binsx = np.linspace(np.min(Omega), np.max(Omega), num_bins)
binsy = np.linspace(np.min(Gravedad), np.max(Gravedad), num_bins)
H2, _, _ = np.histogram2d(Omega, Gravedad, bins=(binsx, binsy))
plt.imshow(H2.T, origin='lower', extent=[binsx[0], binsx[-1], binsy[0], binsy[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Frecuencia')
plt.xlabel('ω')
plt.ylabel('g')
plt.title('Distribución conjunta f(ω, g) para λ = 30')
plt.show()

correlation = np.corrcoef(Omega, Gravedad)
print("Correlación entre ω y g:")
print(correlation)
H1 = np.sum(H2, axis=1)
cs = np.cumsum(H1)
ij = np.searchsorted(cs, np.percentile(cs, 16))
ii = np.searchsorted(cs, np.percentile(cs, 50))
ji = np.searchsorted(cs, np.percentile(cs, 84))
best_estimate = binsx[ii]
confidence_interval = [binsx[ij], binsx[ji]]
sigma_error = np.abs(confidence_interval[0] - best_estimate)
print("Estimador mejor ω: ", best_estimate)
print("Intervalo de confianza a 1σ: ", confidence_interval)
print("σ(+/-ω̂): ", sigma_error)
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.523007
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 8.794165
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.866861
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 36
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.973196
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 6.468805
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 8.450208
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.784088
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.588651
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.914010
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.882981
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 8.394602
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.566160
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.794421
#          Iterations: 2
#          Function evaluations: 92
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.754946
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.926138
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.313999
#          Iterations: 2
#          Function evaluations: 82
#          Gradient evaluations: 35
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.047288
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 4.831893
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.517109
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 2.326145
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.557135
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.100636
#          Iterations: 2
#          Function evaluations: 62
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 7.330743
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.782838
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.347654
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.675183
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.044811
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.001676
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 30
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.431994
#          Iterations: 2
#          Function evaluations: 86
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 3.989730
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.057291
#          Iterations: 2
#          Function evaluations: 66
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 8.702749
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 6.416087
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.275382
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.148701
#          Iterations: 2
#          Function evaluations: 92
#          Gradient evaluations: 40
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.355310
#          Iterations: 2
#          Function evaluations: 82
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 2.599764
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.281571
#          Iterations: 2
#          Function evaluations: 86
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 3.057741
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.801872
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 3.589973
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.704684
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.858123
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.668936
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 6.306274
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.792859
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.190497
#          Iterations: 2
#          Function evaluations: 62
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 4.375455
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.884866
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 5.679419
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.930796
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.408749
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.602551
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 30
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.757367
#          Iterations: 2
#          Function evaluations: 58
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 10.561270
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.820754
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.500022
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.513645
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.473468
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.085466
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.796551
#          Iterations: 2
#          Function evaluations: 58
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 5.089528
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.821403
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 21.408741
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 11.872720
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.888892
#          Iterations: 2
#          Function evaluations: 74
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 5.685025
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.153524
#          Iterations: 2
#          Function evaluations: 56
#          Gradient evaluations: 22
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.510567
#          Iterations: 2
#          Function evaluations: 62
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 10.996752
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.609519
#          Iterations: 2
#          Function evaluations: 68
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 5.993561
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.482090
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 4.055117
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.073985
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 30
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.080131
#          Iterations: 2
#          Function evaluations: 86
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 5.007355
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.918689
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 3.671542
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.825234
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.894154
#          Iterations: 2
#          Function evaluations: 74
#          Gradient evaluations: 31
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.409751
#          Iterations: 2
#          Function evaluations: 56
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 5.709891
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.199843
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.352818
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.805885
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.747587
#          Iterations: 2
#          Function evaluations: 56
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 13.198754
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.981595
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 30
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.654393
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 5.682500
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.330444
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.785020
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.223195
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.329031
#          Iterations: 2
#          Function evaluations: 102
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 8.812407
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.831194
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 11.960273
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.108063
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.298811
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.519172
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.445999
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.607078
#          Iterations: 2
#          Function evaluations: 86
#          Gradient evaluations: 37
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.955958
#          Iterations: 2
#          Function evaluations: 62
#          Gradient evaluations: 25
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.807032
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 7.097159
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 6.769613
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.840726
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 5.818950
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.262145
#          Iterations: 2
#          Function evaluations: 86
#          Gradient evaluations: 37
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.327384
#          Iterations: 2
#          Function evaluations: 88
#          Gradient evaluations: 38
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.255912
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 9.983992
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.962509
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.991842
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.489737
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.256497
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.803981
#          Iterations: 2
#          Function evaluations: 58
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 2.886654
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.871552
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.929308
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 2.185111
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.368204
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.721155
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.365652
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.655257
#          Iterations: 2
#          Function evaluations: 66
#          Gradient evaluations: 27
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.301326
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.282319
#          Iterations: 2
#          Function evaluations: 68
#          Gradient evaluations: 28
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.275048
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 9.236025
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 6.263363
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.259275
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 6.719033
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.351907
#          Iterations: 2
#          Function evaluations: 60
#          Gradient evaluations: 24
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.050060
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 6.743228
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.447395
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.165927
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.708488
#          Iterations: 2
#          Function evaluations: 68
#          Gradient evaluations: 28
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.581921
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 1.329812
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.612445
#          Iterations: 2
#          Function evaluations: 60
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 6.962356
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.792667
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.795321
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 13.103007
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.255471
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.912591
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 30
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.884246
#          Iterations: 2
#          Function evaluations: 68
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 2.343854
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.101634
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 2.357194
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.119791
#          Iterations: 2
#          Function evaluations: 62
#          Gradient evaluations: 25
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.433015
#          Iterations: 2
#          Function evaluations: 60
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 5.683128
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 11.875551
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.512753
#          Iterations: 2
#          Function evaluations: 112
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: 10.731358
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.346309
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.972270
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 9.572074
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.104687
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.855135
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 30
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.738414
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 4.860230
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 8.491605
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 9.192786
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.032209
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 6.851973
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.892621
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 6.125576
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.442870
#          Iterations: 2
#          Function evaluations: 90
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 8.859845
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.297052
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.337074
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 9.435217
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.204942
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 7.209561
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.269177
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.900868
#          Iterations: 2
#          Function evaluations: 82
#          Gradient evaluations: 35
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.697685
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.485957
#          Iterations: 2
#          Function evaluations: 116
#          Gradient evaluations: 52
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.264644
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 3.880993
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 11.455615
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.286774
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.700524
#          Iterations: 2
#          Function evaluations: 106
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 2.875249
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.678172
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.385986
#          Iterations: 2
#          Function evaluations: 82
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 7.567132
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.206912
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.735006
#          Iterations: 2
#          Function evaluations: 90
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 1.643227
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.313837
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 8.697076
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.875262
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 36
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.526696
#          Iterations: 2
#          Function evaluations: 98
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 9.896747
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 4.780763
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.049508
#          Iterations: 2
#          Function evaluations: 82
#          Gradient evaluations: 35
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.928422
#          Iterations: 2
#          Function evaluations: 92
#          Gradient evaluations: 40
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.918715
#          Iterations: 2
#          Function evaluations: 106
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 2.418230
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.585986
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 5.043904
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.978356
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 12.084414
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.295525
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.224348
#          Iterations: 2
#          Function evaluations: 86
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 5.818868
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 6.200899
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.876692
#          Iterations: 2
#          Function evaluations: 92
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 3.470054
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.020811
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 2.276887
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.626351
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 2.683467
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.910418
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 5.670985
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.079844
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 7.795317
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.400094
#          Iterations: 2
#          Function evaluations: 58
#          Gradient evaluations: 23
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.232793
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 6.676937
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.493253
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.747594
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.915696
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.190105
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.476189
#          Iterations: 2
#          Function evaluations: 92
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.937147
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.607731
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 4.294712
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 9.553925
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.933620
#          Iterations: 2
#          Function evaluations: 74
#          Gradient evaluations: 31
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.731795
#          Iterations: 2
#          Function evaluations: 58
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 2.595805
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.911152
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.196706
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.846669
#          Iterations: 2
#          Function evaluations: 52
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 4.170892
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 6.973058
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.440305
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.095514
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 6.257650
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 11.838183
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.356341
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.548507
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 2.050592
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.543126
#          Iterations: 2
#          Function evaluations: 104
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 11.027351
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.376657
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.431855
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.469165
#          Iterations: 2
#          Function evaluations: 88
#          Gradient evaluations: 38
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.152182
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 3.086569
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.071095
#          Iterations: 2
#          Function evaluations: 98
#          Gradient evaluations: 43
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.722619
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.902494
#          Iterations: 2
#          Function evaluations: 100
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 2.219517
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.999123
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.252462
#          Iterations: 2
#          Function evaluations: 74
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 3.553998
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.447796
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 3.512246
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.608893
#          Iterations: 2
#          Function evaluations: 70
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 3.487671
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.329733
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.915439
#          Iterations: 2
#          Function evaluations: 58
#          Gradient evaluations: 23
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.000407
#          Iterations: 2
#          Function evaluations: 64
#          Gradient evaluations: 26
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.887470
#          Iterations: 2
#          Function evaluations: 68
#          Gradient evaluations: 28
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.929063
#          Iterations: 2
#          Function evaluations: 76
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 6.272562
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.399806
#          Iterations: 2
#          Function evaluations: 96
#          Gradient evaluations: 42
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.031222
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 2.455676
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.613237
#          Iterations: 2
#          Function evaluations: 46
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 6.981118
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.411518
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 5.385105
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.351343
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 2.973884
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.393546
#          Iterations: 2
#          Function evaluations: 102
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 2.909577
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 8.152943
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 4.934803
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.824953
#          Iterations: 2
#          Function evaluations: 74
#          Gradient evaluations: 31
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.785326
#          Iterations: 2
#          Function evaluations: 102
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 6.550558
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.734405
#          Iterations: 2
#          Function evaluations: 68
#          Gradient evaluations: 28
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.708488
#          Iterations: 2
#          Function evaluations: 66
#          Gradient evaluations: 27
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.020350
#          Iterations: 2
#          Function evaluations: 80
#          Gradient evaluations: 34
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 6.213618
#          Iterations: 2
#          Function evaluations: 78
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 5.519101
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.981072
#          Iterations: 2
#          Function evaluations: 94
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.366359
#          Iterations: 2
#          Function evaluations: 82
#          Gradient evaluations: 35
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 9.806846
#          Iterations: 2
#          Function evaluations: 86
#          Gradient evaluations: 37
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.191567
#          Iterations: 2
#          Function evaluations: 82
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 7.001291
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 5.933343
#          Iterations: 3
#          Function evaluations: 8
#          Gradient evaluations: 4
# Correlación entre ω y g:
# [[1.        0.7571081]
#  [0.7571081 1.       ]]
# Estimador mejor ω:  7.383705730274857e-05
# Intervalo de confianza a 1σ:  [6.778033761155253e-05, 8.292213683954263e-05]
# σ(+/-ω̂):  6.05671969119604e-06
